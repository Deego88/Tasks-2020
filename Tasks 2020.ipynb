# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Preliminaries" data-toc-modified-id="Preliminaries-1">Preliminaries</a></span></li><li><span><a href="#Task-1---Counts" data-toc-modified-id="Task-1---Counts-2">Task 1 - Counts</a></span><ul class="toc-item"><li><span><a href="#Task-Outline:" data-toc-modified-id="Task-Outline:-2.1">Task Outline:</a></span></li><li><span><a href="#Research" data-toc-modified-id="Research-2.2">Research</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-2.3">Summary</a></span></li></ul></li><li><span><a href="#Task-2--Dicerolls" data-toc-modified-id="Task-2--Dicerolls-3">Task 2- Dicerolls</a></span><ul class="toc-item"><li><span><a href="#Task-Outline" data-toc-modified-id="Task-Outline-3.1">Task Outline</a></span></li><li><span><a href="#Research" data-toc-modified-id="Research-3.2">Research</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-3.3">Summary</a></span></li></ul></li><li><span><a href="#Task-3--Coin-Flip" data-toc-modified-id="Task-3--Coin-Flip-4">Task 3- Coin Flip</a></span><ul class="toc-item"><li><span><a href="#Task-Outline" data-toc-modified-id="Task-Outline-4.1">Task Outline</a></span></li><li><span><a href="#Research" data-toc-modified-id="Research-4.2">Research</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-4.3">Summary</a></span></li></ul></li><li><span><a href="#Task-4--Simpsons-Paradox" data-toc-modified-id="Task-4--Simpsons-Paradox-5">Task 4- Simpsons Paradox</a></span><ul class="toc-item"><li><span><a href="#Task-Outline" data-toc-modified-id="Task-Outline-5.1">Task Outline</a></span></li><li><span><a href="#Research" data-toc-modified-id="Research-5.2">Research</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-5.3">Summary</a></span></li></ul></li><li><span><a href="#References" data-toc-modified-id="References-6">References</a></span></li></ul></div>

# %% [markdown]
# # Preliminaries
#
# import necessary modules

# %%
import random as np
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as ss

# %% [markdown]
#  **Tasks 2020**
#  **Student:** Richard Deegan
#  **Student ID:** G00387896@gmit.ie

# %% [markdown]
# # Task 1 - Counts

# %% [markdown]
# ## Task Outline:
#
# *October 5th, 2020: Write a Python function called counts that takes a list as
# input and returns a dictionary of unique items in the list as keys and the number of
# times each item appears as values. So, the input ['A', 'A', 'B', 'C', 'A']
# should have output {'A': 3, 'B': 1, 'C': 1} . Your code should not depend
# on any module from the standard library1 or otherwise. You should research
# the task first and include a description with references of your algorithm in the
# notebook*

# %% [markdown]
# ## Research
# **Lists**
#
#
# A list is a collection which is ordered and changeable. In Python lists are written with square brackets.
#
# A list is created by placing all the items (elements) inside square brackets [], separated by commas. It can be an integer, float, string or even another (nested) list.
#
# Example:
#     my_list_example = ["mouse", [8, 4, 6], ["a"]]
#
# **The index operator [] is used to access an item in a list**, this starts at 0. Bearing in mind that it's not possible to use float or other types.
#
# You can loop through the list items by using a for loop.
# The count() method returns the number of elements with the specified value.
#
# [2], [3] and [6]

# %% [markdown]
# ![Screenshot%202020-10-11%20144918.png](attachment:Screenshot%202020-10-11%20144918.png)

# %% [markdown]
# <br>
#
# Various built in methonds for lists:
#
#
# ![List_methods.png](attachment:List_methods.png)

# %% [markdown]
# <br>
#
# **Dictionary**
#
# A dictionary is a collection which is unordered, changeable and indexed. This data type which is wrapped in braces, {}, with a series of __key value pairs__ inside the braces. Each key is connected to a value. **We use a key to access the value associated with that key**. A key can be a number, a string, a list, or even another dictionary.
#
# Example:
#     dict={'Name':'Harry','Rollno':30,'Dept':'cse','Marks':97}
#
# You can access the items of a dictionary by referring to its key name, inside square brackets:
#
# x=dict["name"]
#
# Also, you can loop through a dictionary by using a for loop.
#
# When looping through a dictionary, the return value are the keys of the dictionary, but there are methods to return the values as well.
#
# To determine how many items (key-value pairs) a dictionary has, use the len() function.
#
# Example:
#     print(len(dict))
#
# [1], [2], [4] and [5]

# %% [markdown]
# <br>
#
# Various built in methonds for Dictionaries:
#
# ![Dict_methods.png](attachment:Dict_methods.png)

# %%
#  create function called Counts 
def Counts():
    # ask for user input
    x = input("please enter list here:")
    # create new dict
    dict_1 = {}
    # create for loop to loop the range of the user input list
    for index in range (len(x)):
        # the number of times the key is found with the dict is counted
        dict_1[x[index]] = x.count(x[index])
    print(dict_1)
Counts()

# %% [markdown]
# ## Summary
#
# The main difference between Lists and Dictionaries is that Lists are ordered in sequence through index numbers, while Dictionaries are not. Lists use index referencing while Dictionaries use key values. For instance, index 0 on a list would return the first value in the list, while index 1 would return the second value in the list, and so on. A search for dict[0]  would search for the key value of 0 and not index position 0.

# %% [markdown]
# ***

# %% [markdown]
# # Task 2- Dicerolls

# %% [markdown]
# ## Task Outline
# Write a Python function called dicerolls that simulates rolling dice. Your function should take two parameters: the number of dice k and the number of times to roll the dice n. The function should simulate randomly rolling k dice n times, keeping track of each total face value. It should then return a dictionary with the number of times each possible total face value occurred.
# So, calling the function as diceroll(k=2, n=1000) should return a dictionary like:
#
# {2:19,3:50,4:82,5:112,6:135,7:174,8:133,9:114,10:75,11:70,12:36}
#
# You can use any module from the Python standard library you wish and you should include a description with references of your algorithm in the notebook.

# %% [markdown]
# ## Research
#
# At first, I created two dice lists dice_1[1,2,3,4,5,6] and dice_2 [1,2,3,4,5,6]. I then got a random choice from each list and added them together. I struggled at storing a variable output into a list and the code was not very scalable due to the need to manually input new dice lists as the user decided to throw more dice. setting min and max values for the sides of the dice was a more efficient method. The creation of a dictionary to store values in and then subsequently use was utilised. The lessons learnt in Task 1 really proved useful in this regard.

# %%
# ask for user input for K(no.of Dice) and N (no.of Rolls)
k= int(input("please input number of die to roll:"))
n= int(input("please input the number of times to roll the dice:"))

# create function dicerolls with two inputs
def dicerolls(k, n):
    # set values for dice 1-6
    min_val = 1
    max_val = 6
    
    # conditional statement if  number of dice is > 1 then
    if k > 1:
        min_val = k * 1
        max_val = k * 6
    # create a dictionary called "dice" to store values in
    dice = {i:0 for i in range (min_val, max_val + 1)}
    # create a for loop "n" times, use +=1 to add values to total
    for i in range (n):
        dice[random.randint(min_val, max_val)] +=1
    return(dice)
dicerolls(k, n)

# %% [markdown]
# ## Summary

# %% [markdown]
# ***

# %% [markdown]
# # Task 3- Coin Flip

# %% [markdown]
# ## Task Outline
#
# The numpy.random.binomial function can be used to simulate flipping a coin with a 50/50 chance of heads or tails. Interestingly, if a coin is flipped many times then the number of heads is well approximated by a bell-shaped curve. For instance, if we flip a coin 100 times in a row the chance of getting 50 heads is relatively high, the chances of getting 0 or 100 heads is relatively low, and the chances of getting any other number of heads decreases as you move away from 50 in either direction towards 0 or 100. Write some python code that simulates flipping a coin 100 times. Then run this code 1,000 times, keeping track of the number of heads in each of the 1,000 simulations. Select an appropriate plot to depict the resulting list of 1,000 numbers, showing that it roughly follows a bell-shaped curve. You should explain your work in a Markdown cell above the code.

# %%
import random as np
import numpy as np
import random 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# ask for user input on flipping the coin (100 flips) and running the code (1000 times)
n= int(input("please input the number of times flip the coin:"))
k= int(input("please input the number of times to run the code:"))

# create results dictionary with key value pairs
results = {'heads': 0,'tails': 0}

# create "sides" variable that returns a list of all the keys in the results dictionary
sides = list(results.keys())
# create a for loop for k times to run the code (1,000 as per Q)
for i in range(k):
    # create a for loop for n times to flip coin (100 as per Q)
    for i in range(n):
        # add random choice to of heads/tails to a running total
        results[random.choice(sides)] += 1

print('Heads:', results['heads'])
print('Tails:', results['tails'])
# Out:
# please input the number of times flip the coin:100
# please input the number of times to run the code:1000
# Heads: 50122
# Tails: 49878

# %%
# set seaborn style 
sns.set_theme(style="darkgrid")

# use KDE plot to visualise the data.
sns.kdeplot(results, fill=True,)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# We can see that the data contained in the results of the coinflip follows that of a Normal distribution.

# %% [markdown]
# <br>

# %%
sns.histplot(data=results, kde=False)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# We can see that there is a 50% chance of heads and a 50% chance of tails being flipped.

# %% [markdown]
# ## Research

# %% [markdown]
# Dictionary in Python is an unordered collection of data values, used to store data values like a map, which unlike other Data Types that hold only single value as an element, Dictionary holds key : value pair. keys() method in Python Dictionary, returns a view object that displays a list of all the keys in the dictionary [8].
#
# Two for loops were created. one was created to loop over variable "k" which was the number of times the code was to be ran.
# The other for loop was created to loop over variable "n" which was the number of times to flip the coin [9].
#
# Random choice was used to randomly pick between the content in the list "sides" which contains Heads or Tails [10].
#
# Seaborn was used to visualise the data. A KDE plot was chosen as  its a useful method for visualizing the distribution of observations in a dataset, analagous to a histogram which is also shown above. The KDE plot represents the data using a continuous probability density curve in one or more dimensions [11].

# %% [markdown]
# ## Summary

# %% [markdown]
# ***

# %% [markdown]
# # Task 4- Simpsons Paradox

# %% [markdown]
# ## Task Outline
#
# Simpson’s paradox is a well-known statistical paradox
# where a trend evident in a number of groups reverses when the groups are combined
# into one big data set. Use numpy to create four data sets, each with an x array
# and a corresponding y array, to demonstrate Simpson’s paradox. You might
# create your x arrays using numpy.linspace and create the y array for each
# x using notation like y = a * x + b where you choose the a and b for each
# x , y pair to demonstrate the paradox. You might see the Wikipedia page for
# Simpson’s paradox for inspiration.

# %% [markdown]
# ## Research

# %% [markdown]
# Simpson's paradox, which also goes by several other names, is a phenomenon in probability and statistics, in which a trend appears in several different groups of data but disappears or reverses when these groups are combined. This result is often encountered in social-science and medical-science statistics and is particularly problematic when frequency data is unduly given causal interpretations. The paradox can be resolved when causal relations are appropriately addressed in the statistical modeling. It is also referred to as Simpson's reversal, Yule–Simpson effect, amalgamation paradox, or reversal paradox[12]
#
# Taking the University of California, Berkeley as an example lets consider two facts of the data:
#
# Fact 1 :In 1973, at the University of California, Berkeley, the overall acceptance rate in four departments for female applicants was roughly 30%. At the same time, the overall acceptance rate for male applicants was roughly 47% [13]
#
# Fact 2: In each of the departments, the acceptance rate for female applicants was higher than the acceptance rate for male applicants[13]
#
# Both facts sound contradicting, Fact 1 implies that men are more likely to be accepted into the College, while Fact 2 implies women are. the paradox lies in the data and this highlights the importance of comparing the data accurately. Both facts are indeed true. The overall acceptance rate of women is lower than the overall acceptance rate of men. Yet, in each department, the acceptance rate for women is higher than the acceptance rate for men. You may be wondering how this is possible [13].

# %% [markdown]
# ![Gender%20Data.png](attachment:Gender%20Data.png)

# %% [markdown]
# ![Gender%20Data1.png](attachment:Gender%20Data1.png)

# %% [markdown]
# Department 1 accepted both a high number of people and a high percentage of applicants while very few women applied. The same can be said for department 2.
#
# In Departments 3 and 4, the number of women who applied was almost the same as the number of men who applied however the overall acceptance rate was low compared to the other departments.
#
# This is why the overall acceptance rate of women was lower, its not that that women were discriminated against by any departments, its because  women in comparison to men seemed to apply more to very competitive departments where it was really hard to get in.[13]

# %% [markdown]
# ## Summary

# %% [markdown]
# # References
#
# [1] Python Dictionaries: The Definitive Guide: https://www.datacamp.com/community/tutorials/dictionary-python?utm_source=adwords_ppc&utm_campaignid=898687156&utm_adgroupid=48947256715&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=229765585183&utm_targetid=aud-392016246653:dsa-429603003980&utm_loc_interest_ms=&utm_loc_physical_ms=20481&gclid=Cj0KCQjw2or8BRCNARIsAC_ppyYCAKrajeM9Ec6wtdQv3WmxvAMi1niImud8W1zN8LXmrie2pNJTPP0aAo4aEALw_wcB
#
# [2] Python Programming: Creating a dictionary from a list: https://www.youtube.com/watch?v=LcM8h2YoVfg&t=309s
#
# [3] Python List: https://www.programiz.com/python-programming/list
#
# [4] Dictionary Methods in Python Program: https://www.tutorialspoint.com/dictionary-methods-in-python-program
#
# [5] Python Dictionaries: https://www.w3schools.com/python/python_dictionaries.asp
#
# [6] Python | Get a list as input from user: https://www.geeksforgeeks.org/python-get-a-list-as-input-from-user/
#
# [7] Python | Convert a list to dictionary: https://www.geeksforgeeks.org/python-convert-a-list-to-dictionary/
#
# [8] Geeks for Geeks-Python Dictionary.  https://www.geeksforgeeks.org/python-dictionary-keys-method/
#
# [9] Reddit- Code Review: Coin flip streaks. https://www.reddit.com/r/learnpython/comments/dyna2f/code_review_coin_flip_streaks/
#
# [10] pynative- Python random.choice() function to select random item from a List and Set. https://pynative.com/python-random-choice/
#
# [11] seaborn- seaborn.histplot()- https://seaborn.pydata.org/generated/seaborn.kdeplot.html
#
# [12] Simpson's paradox https://en.wikipedia.org/wiki/Simpson%27s_paradox#:~:text=Simpson's%20paradox%2C%20which%20also%20goes,when%20these%20groups%20are%20combined
#
# [13] Gender Bias in Admission Statistics? The Simpson-Paradox. https://towardsdatascience.com/gender-bias-in-admission-statistics-the-simpson-paradox-cd381d994b16
